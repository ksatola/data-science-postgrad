# %%
import numpy as np
import matplotlib.pyplot as plt
#import mkl
from IPython.display import Markdown, display

np.random.seed(1234)
#mkl.set_num_threads(4)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# # Zadanie 1

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [3, 4]])

# %% [markdown]
# ### Wymnóż macierze A i B. Wynik zapisz w macierzy W

# %%
W = A @ B

# %% [markdown]
# ### Test mnożenia macierzy

# %%
if np.trace(W) == 45:
    display(Markdown('#### Prawidłowo!'))
else:
    display(Markdown('#### Błąd!'))
# Out:
# #### Prawidłowo!

# %% [markdown]
# # Zadanie 2
#
# ### Zaimplementuj funkcję sigmoidalną
#
# $\Large\sigma(x) = \frac{1}{1 + e^{-x}}$

# %%
def sigma(x):
    wynik = 1 / (1 + np.exp(-x))
    return wynik

# %% [markdown]
# ### Test funkcji sigmoidalnej

# %%
z = np.random.uniform(size=100)*10.0 - 5.0
z = np.sort(z)

s = sigma(z)
plt.plot(z, s, '.-')

# %% [markdown]
# # Zadanie 3

# %%
a = np.random.uniform(size=100)*3.14*2 - 3.14
a = np.sort(a)

# %% [markdown]
# ### Narysuj wykres $sin(a)$ od $a$.
# Biblioteka do rysowania wykresów jest załadowana pod nazwą `plt`
#
# #### Uwaga: $a$ jest macierzą NumPy

# %%
y = np.sin(a)
plt.plot(a, y)
plt.show();

# %% [markdown]
# # Zadanie 4

# %%
x = np.random.normal(size=1000)
y = np.random.normal(size=1000)

# %% [markdown]
# ### Narysuj scatter plot punktów o współrzędnych x, y.
#
# Biblioteka do rysowania wykresów jest załadowana pod nazwą `plt`

# %%
plt.scatter(x, y)
plt.show();
